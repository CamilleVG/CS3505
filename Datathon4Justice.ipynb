# %% [markdown]
# <a href="https://colab.research.google.com/github/CamilleVG/CS3505/blob/master/Datathon4Justice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Datathon4Justice

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# I am editing this on Google Colab

# %% [markdown]
# Camille is editing this doc right now.  Is anyone else here?

# %% [markdown]
# Testing :)

# %% [markdown]
# Cool, I think I need to save this one to the repository
